# %%
# !pip install pandas

# %%
import pandas as pd

# %%
# https://www.kaggle.com/datasets/mkechinov/ecommerce-behavior-data-from-multi-category-store
# Downlaod the Process 10GB of eCommerce behavior data from a multi-category store using pandas, employing chunking and grouping operations to obtain the finalized aggregated data
df = pd.read_csv('2020-Apr/2020-Apr.csv',chunksize=100000)

# %%
for chunk in df:
    details = chunk[['brand','category_code','event_type']]
    display(details.head())
    break
# Out:
#       brand                     category_code event_type
# 0   samsung             apparel.shoes.slipons       view
# 1     apple       electronics.audio.headphone       view
# 2     apple  appliances.kitchen.refrigerators       view
# 3     apple       electronics.audio.headphone       view
# 4  defender                     apparel.scarf       view

# %%
output = pd.DataFrame()

for chunk in df:
    categories = ['brand','category_code','event_type']
    details = chunk[categories]
    details['count'] = 1
    summary = details.groupby(categories).sum().reset_index()
    output = pd.concat([output,summary],ignore_index=True)
    #output = output.append(summary,ignore_index=True)
# Out:
# C:\Users\satis\AppData\Local\Temp\ipykernel_32708\1044670356.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\satis\AppData\Local\Temp\ipykernel_32708\1044670356.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details['count'] = 1
# C:\Users\satis\AppData\Local\Temp\ipykernel_32708\1044670356.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
output.head()
# Out:
#       brand                category_code event_type  count
# 0    a-case   construction.tools.welding       cart      4
# 1    a-case   construction.tools.welding   purchase      2
# 2    a-case   construction.tools.welding       view     39
# 3    a-mega        furniture.bedroom.bed       view      1
# 4  aardwolf  computers.peripherals.mouse       view      1

# %%
final_output = output.groupby(categories).sum().reset_index()

# %%
final_output.sort_values('count')
# Out:
#           brand             category_code event_type    count
# 10208  himalaya    construction.tools.saw       view        1
# 10980   indiana        apparel.shoes.keds       cart        1
# 2222     bamboo         computers.desktop       view        1
# 19492  scarlett    appliances.kitchen.hob   purchase        1
# 10981   indiana        apparel.shoes.keds   purchase        1
# ...         ...                       ...        ...      ...
# 16266      oppo  construction.tools.light       view   789507
# 10595    huawei  construction.tools.light       view  1151236
# 23755    xiaomi  construction.tools.light       view  1974097
# 1120      apple  construction.tools.light       view  2452113
# 19247   samsung  construction.tools.light       view  5075804
#
# [24200 rows x 4 columns]

# %%
final_output.to_csv('aggregated-customer-info-2020-Apr.csv',index=False)
